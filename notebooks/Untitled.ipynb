# %%
# %pip install sentence_transformers
# Out:
# ...
#   Using cached sentence_transformers-5.2.2-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached transformers-5.1.0-py3-none-any.whl.metadata (31 kB)
# ...
#   Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# ...
# Using cached sentence_transformers-5.2.2-py3-none-any.whl (494 kB)
# Using cached transformers-5.1.0-py3-none-any.whl (10.3 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.3/553.3 kB 9.6 MB/s eta 0:00:00
# Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl (447 kB)
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 1.0.1
#     Uninstalling huggingface-hub-1.0.1:
#       Successfully uninstalled huggingface-hub-1.0.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [sentence_transformers]/4 [transformers]ub]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from sentence_transformers import SentenceTransformer
from datasets import load_from_disk
from tqdm import tqdm

# %%
model = SentenceTransformer('all-MiniLM-L6-v2',device = 'mps')
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
class GetEmbeddings():
    def __init__(self,data_location:str,model_name:str,device:str):
        self.texts :List[str] = []
        try:
            self.model = SentenceTransformer(model_name,device = device)
            print('Successfully loaded the model')
        except Exception as e:
            print(f'Error Loading the model: {e}')
            
        
        try:
            self.data = load_from_disk(data_location)
            print(f'Successfully loaded the data : {data.shape}')
        except Exception as e:
            print(f'Error loading the data: {e}')

    def embedData(self) -> None:
        '''
        This function will embed the data using the model and the device that you have 
        used to embed the model
        '''
        for i in tqdm(range(data.shape[0])):
            for content in data[i]['conversation']:
                self.texts.append(content['content'])

        print(f'Length of text : {len(self.texts)}')

        embeddings = self.model.encode(
            self.texts,
            batch_size=64
            show_progress_bar = True,
            convert_to_numpy = True
        )

        np.save('')

# %%
# # for i in range(10):
#     for content in data[i]['conversation']:
#         print(content['content'])
#         print('\n')
#     print('\n')

# %%
embeddings = GetEmbeddings(data_location='../data/processed/train_data/',model_name='all-MiniLM-L6-v2',device='mps')
embeddings.embedData()
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Successfully loaded the model
# Successfully loaded the data : (437701, 7)
# 100%|██████████████████████| 437701/437701 [00:32<00:00, 13649.73it/s]
# Length of text : 1621272
